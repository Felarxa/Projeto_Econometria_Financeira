# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from lxml import etree
import yfinance as yf

# %%
ticker = "MGLU3"
base_url = f"https://www.dadosdemercado.com.br/acoes/{ticker}"
try:
    response = requests.get(base_url)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    print(f"Erro ao acessar página principal de ELET3: {e}")

soup = BeautifulSoup(response.text, 'html.parser')
tables = soup.find_all(attrs={'id': ('balances', 'cashflows', 'incomesYear')})
# Out:
# [<div class="table-container high bordered slide" id="balances">
#  <table class="normal-table">
#  <thead>
#  <tr>
#  <th>Conta</th>
#  <th class="right">1T2025</th>
#  <th class="right">4T2024</th>
#  <th class="right">3T2024</th>
#  <th class="right">2T2024</th>
#  <th class="right">1T2024</th>
#  <th class="right">4T2023</th>
#  <th class="right">3T2023</th>
#  <th class="right">2T2023</th>
#  <th class="right">1T2023</th>
#  <th class="right">4T2022</th>
#  <th class="right">3T2022</th>
#  <th class="right">2T2022</th>
#  <th class="right">1T2022</th>
#  <th class="right">4T2021</th>
#  <th class="right">3T2021</th>
#  <th class="right">2T2021</th>
#  <th class="right">1T2021</th>
#  <th class="right">4T2020</th>
#  <th class="right">3T2020</th>
#  <th class="right">2T2020</th>
#  <th class="right">1T2020</th>
#  <th class="right">4T2019</th>
#  <th class="right">3T2019</th>
#  <th class="right">2T2019</th>
#  <th class="right">1T2019</th>
#  <th class="right">4T2018</th>
#  <th class="right">3T2018</th>
#  <th class="right">2T2018</th>
#  <th class="right">1T2018</th>
#  <th class="right">4T2017</th>
#  <th class="right">3T2017</th>
#  <th class="right">2T2017</th>
#  <th class="right">1T2017</th>
#  <th class="right">4T2016</th>
#  <th class="right">3T2016</th>
#  <th class="right">2T2016</th>
#  <th class="right">1T2016</th>
#  <th class="right">4T2015</th>
#  <th class="right">3T2015</th>
#  <th class="right">2T2015</th>
#  <th class="right">1T2015</th>
#  <th class="right">4T2014</th>
#  <th class="right">3T2014</th>
#  <th class="right">2T2014</th>
#  <th class="right">1T2014</th>
#  <th class="right">4T2013</th>
#  <th class="right">3T2013</th>
#  <th class="right">2T2013</th>
#  <th class="right">1T2013</th>
#  <th class="right">4T2012</th>
#  <th class="right">3T2012</th>
#  <th class="right">2T2012</th>
#  <th class="right">1T2012</th>
#  <th class="right">4T2011</th>
#  <th class="right">3T2011</th>
#  <th class="right">2T2011</th>
#  <th class="right">1T2011</th>
#  <th class="right">4T2010</th>
#  <th class="right">4T2009</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="level0">
#  <td class="nw">Ativo total</td>
#  <td class="right nw">
#
#                      35,58 B
#
#                  </td>
#  <td class="right nw">
#
#                      37,31 B
#
#                  </td>
#  <td class="right nw">
#
#                      35,70 B
#
#                  </td>
#  <td class="right nw">
#
#                      34,98 B
#
#                  </td>
#  <td class="right nw">
#
#                      37,22 B
#
#                  </td>
#  <td class="right nw">
#
#                      37,46 B
#
#                  </td>
#  <td class="right nw">
#
#                      36,92 B
#
#                  </td>
#  <td class="right nw">
#
#                      35,60 B
#
#                  </td>
#  <td class="right nw">
#
#                      34,22 B
#
#                  </td>
#  <td class="right nw">
#
#                      37,77 B
#
#                  </td>
#  <td class="right nw">
#
#                      35,98 B
#
#                  </td>
#  <td class="right nw">
#
#                      34,50 B
#
#                  </td>
#  <td class="right nw">
#
#                      33,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      38,38 B
#
#                  </td>
#  <td class="right nw">
#
#                      30,55 B
#
#                  </td>
#  <td class="right nw">
#
#                      25,07 B
#
#                  </td>
#  <td class="right nw">
#
#                      22,61 B
#
#                  </td>
#  <td class="right nw">
#
#                      24,65 B
#
#                  </td>
#  <td class="right nw">
#
#                      21,81 B
#
#                  </td>
#  <td class="right nw">
#
#                      20,56 B
#
#                  </td>
#  <td class="right nw">
#
#                      17,71 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,79 B
#
#                  </td>
#  <td class="right nw">
#
#                      13,25 B
#
#                  </td>
#  <td class="right nw">
#
#                      12,08 B
#
#                  </td>
#  <td class="right nw">
#
#                      9,74 B
#
#                  </td>
#  <td class="right nw">
#
#                      8,80 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,13 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,04 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,90 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,42 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,95 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,27 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,27 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,10 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,20 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,98 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,98 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,50 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,78 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,66 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,83 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,25 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,66 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,49 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,48 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,71 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,35 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,29 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,11 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,11 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,23 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,12 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,85 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,88 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,44 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,40 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,68 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,93 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,63 B
#
#                  </td>
#  </tr>
#  <tr class="level1">
#  <td class="nw">Ativo circulante</td>
#  <td class="right nw">
#
#                      18,06 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,55 B
#
#                  </td>
#  <td class="right nw">
#
#                      17,75 B
#
#                  </td>
#  <td class="right nw">
#
#                      17,39 B
#
#                  </td>
#  <td class="right nw">
#
#                      20,05 B
#
#                  </td>
#  <td class="right nw">
#
#                      20,22 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,48 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,09 B
#
#                  </td>
#  <td class="right nw">
#
#                      18,18 B
#
#                  </td>
#  <td class="right nw">
#
#                      21,94 B
#
#                  </td>
#  <td class="right nw">
#
#                      20,72 B
#
#                  </td>
#  <td class="right nw">
#
#                      20,07 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,59 B
#
#                  </td>
#  <td class="right nw">
#
#                      24,51 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,87 B
#
#                  </td>
#  <td class="right nw">
#
#                      15,99 B
#
#                  </td>
#  <td class="right nw">
#
#                      14,62 B
#
#                  </td>
#  <td class="right nw">
#
#                      16,80 B
#
#                  </td>
#  <td class="right nw">
#
#                      14,36 B
#
#                  </td>
#  <td class="right nw">
#
#                      13,28 B
#
#                  </td>
#  <td class="right nw">
#
#                      10,59 B
#
#                  </td>
#  <td class="right nw">
#
#                      12,84 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,35 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,04 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,33 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,41 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,89 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,84 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,77 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,26 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,79 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,12 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,13 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,92 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,01 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,81 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,82 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,36 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,64 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,67 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,92 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,40 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,63 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,68 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,92 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,63 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,62 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,39 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,42 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,83 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,74 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,50 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,57 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,24 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,32 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,67 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,90 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,01 B
#
#                  </td>
#  </tr>
#  <tr class="level2">
#  <td class="nw">Caixa e eq. de caixa</td>
#  <td class="right nw">
#
#                      1,53 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,83 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,54 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,21 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,98 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,59 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,80 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,10 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,78 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,42 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,81 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,71 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,41 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,57 B
#
#                  </td>
#  <td class="right nw">
#
#                      751,22 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,29 B
#
#                  </td>
#  <td class="right nw">
#
#                      639,87 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,68 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,19 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,10 B
#
#                  </td>
#  <td class="right nw">
#
#                      388,90 M
#
#                  </td>
#  <td class="right nw">
#
#                      305,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      221,79 M
#
#                  </td>
#  <td class="right nw">
#
#                      625,71 M
#
#                  </td>
#  <td class="right nw">
#
#                      293,19 M
#
#                  </td>
#  <td class="right nw">
#
#                      599,09 M
#
#                  </td>
#  <td class="right nw">
#
#                      419,01 M
#
#                  </td>
#  <td class="right nw">
#
#                      680,45 M
#
#                  </td>
#  <td class="right nw">
#
#                      775,15 M
#
#                  </td>
#  <td class="right nw">
#
#                      412,71 M
#
#                  </td>
#  <td class="right nw">
#
#                      178,62 M
#
#                  </td>
#  <td class="right nw">
#
#                      265,06 M
#
#                  </td>
#  <td class="right nw">
#
#                      255,09 M
#
#                  </td>
#  <td class="right nw">
#
#                      599,14 M
#
#                  </td>
#  <td class="right nw">
#
#                      234,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      197,50 M
#
#                  </td>
#  <td class="right nw">
#
#                      411,26 M
#
#                  </td>
#  <td class="right nw">
#
#                      617,47 M
#
#                  </td>
#  <td class="right nw">
#
#                      270,39 M
#
#                  </td>
#  <td class="right nw">
#
#                      227,14 M
#
#                  </td>
#  <td class="right nw">
#
#                      282,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      412,17 M
#
#                  </td>
#  <td class="right nw">
#
#                      132,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      287,37 M
#
#                  </td>
#  <td class="right nw">
#
#                      235,28 M
#
#                  </td>
#  <td class="right nw">
#
#                      280,31 M
#
#                  </td>
#  <td class="right nw">
#
#                      260,30 M
#
#                  </td>
#  <td class="right nw">
#
#                      176,57 M
#
#                  </td>
#  <td class="right nw">
#
#                      152,28 M
#
#                  </td>
#  <td class="right nw">
#
#                      418,88 M
#
#                  </td>
#  <td class="right nw">
#
#                      99,03 M
#
#                  </td>
#  <td class="right nw">
#
#                      140,30 M
#
#                  </td>
#  <td class="right nw">
#
#                      176,12 M
#
#                  </td>
#  <td class="right nw">
#
#                      173,12 M
#
#                  </td>
#  <td class="right nw">
#
#                      77,97 M
#
#                  </td>
#  <td class="right nw">
#
#                      48,31 M
#
#                  </td>
#  <td class="right nw">
#
#                      125,62 M
#
#                  </td>
#  <td class="right nw">
#
#                      328,87 M
#
#                  </td>
#  <td class="right nw">
#
#                      192,41 M
#
#                  </td>
#  </tr>
#  <tr class="level2">
#  <td class="nw">Aplicações financeiras</td>
#  <td class="right nw">
#
#                      201,33 M
#
#                  </td>
#  <td class="right nw">
#
#                      337,89 M
#
#                  </td>
#  <td class="right nw">
#
#                      269,53 M
#
#                  </td>
#  <td class="right nw">
#
#                      739,12 M
#
#                  </td>
#  <td class="right nw">
#
#                      352,06 M
#
#                  </td>
#  <td class="right nw">
#
#                      779,07 M
#
#                  </td>
#  <td class="right nw">
#
#                      480,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      386,19 M
#
#                  </td>
#  <td class="right nw">
#
#                      447,91 M
#
#                  </td>
#  <td class="right nw">
#
#                      304,30 M
#
#                  </td>
#  <td class="right nw">
#
#                      293,88 M
#
#                  </td>
#  <td class="right nw">
#
#                      211,31 M
#
#                  </td>
#  <td class="right nw">
#
#                      584,43 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,56 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,35 B
#
#                  </td>
#  <td class="right nw">
#
#                      468,47 M
#
#                  </td>
#  <td class="right nw">
#
#                      745,39 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,22 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,73 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,88 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,23 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,45 B
#
#                  </td>
#  <td class="right nw">
#
#                      238,72 M
#
#                  </td>
#  <td class="right nw">
#
#                      441,10 M
#
#                  </td>
#  <td class="right nw">
#
#                      217,28 M
#
#                  </td>
#  <td class="right nw">
#
#                      409,11 M
#
#                  </td>
#  <td class="right nw">
#
#                      253,76 M
#
#                  </td>
#  <td class="right nw">
#
#                      182,84 M
#
#                  </td>
#  <td class="right nw">
#
#                      299,35 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,26 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,04 B
#
#                  </td>
#  <td class="right nw">
#
#                      596,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      521,38 M
#
#                  </td>
#  <td class="right nw">
#
#                      818,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      566,95 M
#
#                  </td>
#  <td class="right nw">
#
#                      464,85 M
#
#                  </td>
#  <td class="right nw">
#
#                      302,25 M
#
#                  </td>
#  <td class="right nw">
#
#                      497,62 M
#
#                  </td>
#  <td class="right nw">
#
#                      265,14 M
#
#                  </td>
#  <td class="right nw">
#
#                      238,79 M
#
#                  </td>
#  <td class="right nw">
#
#                      337,43 M
#
#                  </td>
#  <td class="right nw">
#
#                      450,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      435,16 M
#
#                  </td>
#  <td class="right nw">
#
#                      283,76 M
#
#                  </td>
#  <td class="right nw">
#
#                      306,27 M
#
#                  </td>
#  <td class="right nw">
#
#                      491,29 M
#
#                  </td>
#  <td class="right nw">
#
#                      423,49 M
#
#                  </td>
#  <td class="right nw">
#
#                      539,04 M
#
#                  </td>
#  <td class="right nw">
#
#                      476,23 M
#
#                  </td>
#  <td class="right nw">
#
#                      126,39 M
#
#                  </td>
#  <td class="right nw">
#
#                      274,33 M
#
#                  </td>
#  <td class="right nw">
#
#                      255,06 M
#
#                  </td>
#  <td class="right nw">
#
#                      162,70 M
#
#                  </td>
#  <td class="right nw">
#
#                      74,96 M
#
#                  </td>
#  <td class="right nw">
#
#                      259,47 M
#
#                  </td>
#  <td class="right nw">
#
#                      655,52 M
#
#                  </td>
#  <td class="right nw">
#
#                      145,34 M
#
#                  </td>
#  <td class="right nw">
#
#                      46,73 M
#
#                  </td>
#  <td class="right nw">
#
#                      39,21 M
#
#                  </td>
#  </tr>
#  <tr class="level2">
#  <td class="nw">Contas a receber</td>
#  <td class="right nw">
#
#                      4,95 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,83 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,78 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,54 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,05 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,89 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,84 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,53 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,72 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,49 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,62 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,80 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,65 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,43 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,78 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,71 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,03 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,39 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,15 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,92 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,87 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,46 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,05 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,66 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,51 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,41 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,24 B
#
#                  </td>
#  <td class="right nw">
#
#                      663,19 M
#
#                  </td>
#  <td class="right nw">
#
#                      503,85 M
#
#                  </td>
#  <td class="right nw">
#
#                      578,85 M
#
#                  </td>
#  <td class="right nw">
#
#                      581,00 M
#
#                  </td>
#  <td class="right nw">
#
#                      423,05 M
#
#                  </td>
#  <td class="right nw">
#
#                      404,30 M
#
#                  </td>
#  <td class="right nw">
#
#                      389,64 M
#
#                  </td>
#  <td class="right nw">
#
#                      435,23 M
#
#                  </td>
#  <td class="right nw">
#
#                      431,18 M
#
#                  </td>
#  <td class="right nw">
#
#                      419,45 M
#
#                  </td>
#  <td class="right nw">
#
#                      480,44 M
#
#                  </td>
#  <td class="right nw">
#
#                      618,28 M
#
#                  </td>
#  <td class="right nw">
#
#                      583,81 M
#
#                  </td>
#  <td class="right nw">
#
#                      577,42 M
#
#                  </td>
#  <td class="right nw">
#
#                      510,04 M
#
#                  </td>
#  <td class="right nw">
#
#                      530,62 M
#
#                  </td>
#  <td class="right nw">
#
#                      463,68 M
#
#                  </td>
#  <td class="right nw">
#
#                      458,45 M
#
#                  </td>
#  <td class="right nw">
#
#                      448,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      486,47 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,96 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,97 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,88 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,93 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,76 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,63 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,52 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,52 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,19 B
#
#                  </td>
#  </tr>
#  <tr class="level2">
#  <td class="nw">Estoques</td>
#  <td class="right nw">
#
#                      7,19 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,61 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,39 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,20 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,32 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,50 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,90 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,57 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,56 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,79 B
#
#                  </td>
#  <td class="right nw">
#
#                      8,47 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,97 B
#
#                  </td>
#  <td class="right nw">
#
#                      8,08 B
#
#                  </td>
#  <td class="right nw">
#
#                      9,11 B
#
#                  </td>
#  <td class="right nw">
#
#                      8,13 B
#
#                  </td>
#  <td class="right nw">
#
#                      7,50 B
#
#                  </td>
#  <td class="right nw">
#
#                      6,81 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,93 B
#
#                  </td>
#  <td class="right nw">
#
#                      5,01 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,20 B
#
#                  </td>
#  <td class="right nw">
#
#                      4,08 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,80 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,89 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,56 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,48 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,81 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,11 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,11 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,94 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,97 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,55 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,43 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,45 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,60 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,35 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,31 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,28 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,35 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,21 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,29 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,39 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,47 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,27 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,14 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,26 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,25 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,14 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,05 B
#
#                  </td>
#  <td class="right nw">
#
#                      974,92 M
#
#                  </td>
#  <td class="right nw">
#
#                      1,07 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,31 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,13 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,13 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,26 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,00 B
#
#                  </td>
#  <td class="right nw">
#
#                      876,60 M
#
#                  </td>
#  <td class="right nw">
#
#                      741,13 M
#
#                  </td>
#  <td class="right nw">
#
#                      849,80 M
#
#                  </td>
#  <td class="right nw">
#
#                      518,55 M
#
#                  </td>
#  </tr>
#  <tr class="level2">
#  <td class="nw">Ativos biológicos</td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
# ...
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  </tr>
#  <tr class="level0">
#  <td class="nw">Lucro líquido</td>
#  <td class="right nw">
#
#                      433,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      448,72 M
#
#                  </td>
#  <td class="right nw">
#
#                      -979,10 M
#
#                  </td>
#  <td class="right nw">
#
#                      -498,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      590,66 M
#
#                  </td>
#  <td class="right nw">
#
#                      391,71 M
#
#                  </td>
#  <td class="right nw">
#
#                      921,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      597,43 M
#
#                  </td>
#  <td class="right nw">
#
#                      389,02 M
#
#                  </td>
#  <td class="right nw">
#
#                      86,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      -65,61 M
#
#                  </td>
#  <td class="right nw">
#
#                      128,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      113,81 M
#
#                  </td>
#  <td class="right nw">
#
#                      -6,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      11,67 M
#
#                  </td>
#  <td class="right nw">
#
#                      68,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      -92,71 M
#
#                  </td>
#  </tr>
#  <tr class="level1">
#  <td class="nw">Dos controladores</td>
#  <td class="right nw">
#
#                      433,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      448,72 M
#
#                  </td>
#  <td class="right nw">
#
#                      -979,10 M
#
#                  </td>
#  <td class="right nw">
#
#                      -498,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      590,66 M
#
#                  </td>
#  <td class="right nw">
#
#                      391,71 M
#
#                  </td>
#  <td class="right nw">
#
#                      921,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      597,43 M
#
#                  </td>
#  <td class="right nw">
#
#                      389,02 M
#
#                  </td>
#  <td class="right nw">
#
#                      86,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      -65,61 M
#
#                  </td>
#  <td class="right nw">
#
#                      128,56 M
#
#                  </td>
#  <td class="right nw">
#
#                      113,81 M
#
#                  </td>
#  <td class="right nw">
#
#                      -6,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      11,67 M
#
#                  </td>
#  <td class="right nw">
#
#                      68,83 M
#
#                  </td>
#  <td class="right nw">
#
#                      -92,71 M
#
#                  </td>
#  </tr>
#  <tr class="level1">
#  <td class="nw">Dos não controladores</td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  <td class="right nw">
#
#                      0
#
#                  </td>
#  </tr>
#  </tbody>
#  </table>
#  <div class="table-footer">
#  <button class="btn no-icon scroll-left">Anterior</button>
#  <button class="btn no-icon scroll-right">Próximo</button>
#  </div>
#  </div>,
#  <div class="table-container high bordered slide" id="cashflows">
#  <table class="normal-table">
#  <thead>
#  <tr>
#  <th>Conta</th>
#  <th class="right">2024</th>
#  <th class="right">2023</th>
#  <th class="right">2022</th>
#  <th class="right">2021</th>
#  <th class="right">2020</th>
#  <th class="right">2019</th>
#  <th class="right">2018</th>
#  <th class="right">2017</th>
#  <th class="right">2016</th>
#  <th class="right">2015</th>
#  <th class="right">2014</th>
#  <th class="right">2013</th>
#  <th class="right">2012</th>
#  <th class="right">2011</th>
#  <th class="right">2010</th>
#  <th class="right">2009</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="level0">
#  <td class="nw">Caixa líq. operac.</td>
#  <td class="right nw">
#
#                      15,84 B
#
#                  </td>
#  <td class="right nw">
#
#                      15,90 B
#
#                  </td>
#  <td class="right nw">
#
#                      3,06 B
#
#                  </td>
#  <td class="right nw">
#
#                      -7,57 B
#
#                  </td>
#  <td class="right nw">
#
#                      2,60 B
#
#                  </td>
#  <td class="right nw">
#
#                      -3,33 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,24 B
#
#                  </td>
#  <td class="right nw">
#
#                      19,48 M
#
#                  </td>
#  <td class="right nw">
#
#                      267,75 M
#
#                  </td>
#  <td class="right nw">
#
#                      462,79 M
#
#                  </td>
#  <td class="right nw">
#
#                      131,44 M
#
#                  </td>
#  <td class="right nw">
#
#                      -136,24 M
#
#                  </td>
#  <td class="right nw">
#
#                      -25,59 M
#
#                  </td>
#  <td class="right nw">
#
#                      -263,58 M
#
#                  </td>
#  <td class="right nw">
#
#                      405,41 M
#
#                  </td>
#  <td class="right nw">
#
#                      172,56 M
#
#                  </td>
#  </tr>
#  <tr class="level1">
#  <td class="nw">Dep. e amortização</td>
#  <td class="right nw">
#
#                      1,33 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,24 B
#
#                  </td>
#  <td class="right nw">
#
#                      1,16 B
#
#                  </td>
#  <td class="right nw">
#
#                      816,96 M
#
#                  </td>
#  <td class="right nw">
#
#                      702,52 M
#
#                  </td>
#  <td class="right nw">
#
#                      486,98 M
#
#                  </td>
#  <td class="right nw">
#
#                      163,69 M
#
#                  </td>
#  <td class="right nw">
#
#                      143,06 M
#
#                  </td>
#  <td class="right nw">
#
#                      133,61 M
#
#                  </td>
#  <td class="right nw">
#
#                      125,80 M
#
#                  </td>
#  <td class="right nw">
#
#                      114,33 M
#
#                  </td>
#  <td class="right nw">
#
#                      101,96 M
#
#                  </td>
#  <td class="right nw">
#
#                      92,45 M
#
#                  </td>
#  <td class="right nw">
#
#                      86,94 M
#
#                  </td>
#  <td class="right nw">
#
#                      68,49 M
#
#                  </td>
#  <td class="right nw">
#
#                      60,62 M
#
#                  </td>
#  </tr>
#  <tr class="level0">
#  <td class="nw">Caixa líq. financ.</td>
#  <td class="right nw">
#
#                      -1,29 B
#
#                  </td>
#  <td class="right nw">
#
#                      -148,40 M
#
#                  </td>
#  <td class="right nw">
#
#                      -1,04 B
#
#                  </td>
#  <td class="right nw">
#
#                      -1,32 B
#
#                  </td>
#  <td class="right nw">
#
#                      -651,45 M
#
#                  </td>
#  <td class="right nw">
#
#                      -928,59 M
#
#                  </td>
#  <td class="right nw">
#
#                      -394,11 M
#
#                  </td>
#  <td class="right nw">
#
#                      -168,66 M
#
#                  </td>
#  <td class="right nw">
#
#                      -135,53 M
#
#                  </td>
#  <td class="right nw">
#
#                      60,85 M
#
#                  </td>
#  <td class="right nw">
#
#                      -152,93 M
#
#                  </td>
#  <td class="right nw">
#
#                      53,16 M
#
#                  </td>
#  <td class="right nw">
#
#                      -148,78 M
#
#                  </td>
#  <td class="right nw">
#
#                      -270,39 M
#
#                  </td>
#  <td class="right nw">
#
#                      -105,48 M
#
#                  </td>
#  <td class="right nw">
#
#                      203,40 M
#
#                  </td>
#  </tr>
#  <tr class="level0">
#  <td class="nw">Caixa líq. invest.</td>
#  <td class="right nw">
#
#                      -15,31 B
#
#                  </td>
#  <td class="right nw">
#
#                      -15,58 B
#
#                  </td>
#  <td class="right nw">
#
#                      -2,17 B
#
#                  </td>
#  <td class="right nw">
#
#                      9,77 B
#
#                  </td>
#  <td class="right nw">
#
#                      -576,81 M
#
#                  </td>
#  <td class="right nw">
#
#                      3,96 B
#
#                  </td>
#  <td class="right nw">
#
#                      -655,67 M
#
#                  </td>
#  <td class="right nw">
#
#                      -37,25 M
#
#                  </td>
#  <td class="right nw">
#
#                      -150,54 M
#
#                  </td>
#  <td class="right nw">
#
#                      -318,34 M
#
#                  </td>
#  <td class="right nw">
#
#                      153,36 M
#
#                  </td>
#  <td class="right nw">
#
#                      -55,49 M
#
#                  </td>
#  <td class="right nw">
#
#                      423,97 M
#
#                  </td>
#  <td class="right nw">
#
#                      378,22 M
#
#                  </td>
#  <td class="right nw">
#
#                      -163,47 M
#
#                  </td>
#  <td class="right nw">
#
#                      -219,05 M
#
#                  </td>
#  </tr>
#  </tbody>
#  </table>
#  <div class="table-footer">
#  <button class="btn no-icon scroll-left">Anterior</button>
#  <button class="btn no-icon scroll-right">Próximo</button>
#  </div>
#  </div>]

# %%
i = 0
for idx, table in enumerate(tables):
    rows = table.find_all('tr')
    table_data = []

    for row in rows:
        headers_in_row = row.find_all('th')
        if headers_in_row:
            cols = [ele.text.strip() for ele in headers_in_row]
        else:
            cols = [ele.text.strip() for ele in row.find_all('td')]
        table_data.append(cols)
    var = 'df' + str(i)
    vars()[var] = pd.DataFrame(table_data)
    i += 1

# %%
for i in range(0,3):
    var = 'df' + str(i)
    vars()[var].columns = vars()[var].iloc[0]
    vars()[var] = vars()[var][1:].reset_index(drop=True)

# %%
df0
# Out:
# 0                     Conta    1T2025    4T2024    3T2024    2T2024    1T2024  \
# 0               Ativo total   35,58 B   37,31 B   35,70 B   34,98 B   37,22 B
# 1          Ativo circulante   18,06 B   19,55 B   17,75 B   17,39 B   20,05 B
# 2      Caixa e eq. de caixa    1,53 B    1,83 B    1,54 B    1,21 B    1,98 B
# 3    Aplicações financeiras  201,33 M  337,89 M  269,53 M  739,12 M  352,06 M
# 4          Contas a receber    4,95 B    5,83 B    4,78 B    4,54 B    6,05 B
# 5                  Estoques    7,19 B    7,61 B    7,39 B    7,20 B    7,32 B
# 6         Ativos biológicos         0         0         0         0         0
# 7      Ativo não circulante   17,52 B   17,76 B   17,96 B   17,59 B   17,17 B
# 8             Investimentos    1,01 B  971,86 M  898,73 M  565,48 M  329,77 M
# 9               Imobilizado    5,02 B    5,07 B    5,04 B    4,96 B    5,07 B
# 10               Intangível    4,48 B    4,48 B    4,47 B    4,52 B    4,53 B
# 11            Passivo total   35,58 B   37,31 B   35,70 B   34,98 B   37,22 B
# 12       Passivo circulante   15,03 B   16,71 B   14,31 B   13,43 B   15,90 B
# 13             Fornecedores    8,92 B   10,28 B    9,05 B    8,79 B    8,60 B
# 14    Empréstimos e financ.    1,47 B    1,40 B  643,43 M   57,15 M    2,27 B
# 15   Passivo não circulante    9,19 B    9,28 B   10,33 B   10,57 B   10,42 B
# 16  Emprést. de longo prazo    3,12 B    3,18 B    4,20 B    4,40 B    4,40 B
# 17       Patrimônio líquido   11,36 B   11,32 B   11,06 B   10,97 B   10,90 B
# 18    Aos não controladores         0         0         0         0         0
#
# 0     4T2023    3T2023    2T2023    1T2023  ...    4T2012    3T2012    2T2012  \
# 0    37,46 B   36,92 B   35,60 B   34,22 B  ...    4,11 B    5,23 B    5,12 B
# 1    20,22 B   19,48 B   19,09 B   18,18 B  ...    2,42 B    3,83 B    3,74 B
# 2     2,59 B    2,80 B    2,10 B    1,78 B  ...  418,88 M   99,03 M  140,30 M
# 3   779,07 M  480,83 M  386,19 M  447,91 M  ...  126,39 M  274,33 M  255,06 M
# 4     5,89 B    4,84 B    5,53 B    4,72 B  ...  486,47 M    1,96 B    1,97 B
# 5     7,50 B    7,90 B    7,57 B    7,56 B  ...    1,07 B    1,31 B    1,13 B
# 6          0         0         0         0  ...         0         0         0
# 7    17,23 B   17,44 B   16,51 B   16,04 B  ...    1,69 B    1,40 B    1,38 B
# 8   322,52 M  264,05 M  282,26 M  301,65 M  ...  222,89 M         0         0
# 9     5,18 B    5,25 B    5,42 B    5,38 B  ...  573,96 M  552,03 M  529,16 M
# 10    4,50 B    4,48 B    4,47 B    4,45 B  ...  435,34 M  441,03 M  443,23 M
# 11   37,46 B   36,92 B   35,60 B   34,22 B  ...    4,11 B    5,23 B    5,12 B
# 12   17,41 B   17,13 B   15,25 B   12,78 B  ...    2,01 B    3,21 B    3,07 B
# 13    9,32 B    9,31 B    7,87 B    7,00 B  ...    1,33 B    1,18 B    1,02 B
# 14    2,95 B    3,00 B    2,83 B    1,05 B  ...  317,20 M  222,98 M  225,90 M
# 15   10,44 B   10,26 B   10,34 B   11,15 B  ...    1,48 B    1,41 B    1,44 B
# 16    4,40 B    4,40 B    4,40 B    6,22 B  ...  918,77 M  892,57 M  901,00 M
# 17    9,61 B    9,53 B   10,01 B   10,29 B  ...  615,99 M  605,56 M  602,53 M
# 18         0         0         0         0  ...         0         0         0
#
# 0     1T2012    4T2011    3T2011    2T2011    1T2011    4T2010    4T2009
# 0     4,85 B    4,88 B    4,44 B    4,40 B    3,68 B    3,93 B    2,63 B
# 1     3,50 B    3,57 B    3,24 B    3,32 B    2,67 B    2,90 B    2,01 B
# 2   176,12 M  173,12 M   77,97 M   48,31 M  125,62 M  328,87 M  192,41 M
# 3   162,70 M   74,96 M  259,47 M  655,52 M  145,34 M   46,73 M   39,21 M
# 4     1,88 B    1,93 B    1,76 B    1,63 B    1,52 B    1,52 B    1,19 B
# 5     1,13 B    1,26 B    1,00 B  876,60 M  741,13 M  849,80 M  518,55 M
# 6          0         0         0         0         0         0         0
# 7     1,35 B    1,31 B    1,20 B    1,08 B    1,01 B    1,03 B  622,80 M
# 8          0         0         0         0         0         0         0
# 9   513,74 M  489,94 M  406,58 M  372,57 M  359,86 M  358,84 M  297,79 M
# 10  447,13 M  448,91 M  448,55 M  374,92 M  370,02 M  374,62 M   86,66 M
# 11    4,85 B    4,88 B    4,44 B    4,40 B    3,68 B    3,93 B    2,63 B
# 12    2,89 B    3,17 B    2,72 B    2,74 B    2,54 B    2,69 B    1,84 B
# 13    1,04 B    1,27 B  988,14 M  923,71 M  756,72 M    1,13 B  696,05 M
# 14  122,38 M  129,67 M  140,79 M  332,70 M  350,12 M  108,76 M  168,12 M
# 15    1,38 B    1,09 B    1,08 B    1,03 B    1,09 B    1,19 B  802,74 M
# 16  863,23 M  581,66 M  617,15 M  516,18 M  595,39 M  666,12 M  527,72 M
# 17  581,00 M  620,95 M  639,50 M  627,82 M   59,73 M   47,44 M   -6,06 M
# 18         0         0         0         0         0         0         0
#
# [19 rows x 60 columns]

# %%
df1
# Out:
# 0                   Conta 1T2025 (TTM)      2024       2023       2022  \
# 0         Receita líquida      38,19 B   38,04 B    36,77 B    37,30 B
# 1                  Custos     -26,45 B  -26,41 B   -26,60 B   -26,86 B
# 2             Lucro bruto      11,74 B   11,63 B    10,16 B    10,44 B
# 3   Despesas operacionais     -10,10 B  -10,06 B   -10,54 B    -9,67 B
# 4                    EBIT       1,64 B    1,56 B  -372,15 M   771,63 M
# 5    Resultado financeiro      -1,58 B   -1,48 B    -1,69 B    -2,04 B
# 6      Antes dos impostos      58,60 M   87,38 M    -2,06 B    -1,27 B
# 7                 Imposto     374,96 M  361,33 M     1,09 B   770,42 M
# 8         Op. continuadas     433,56 M  448,72 M  -979,10 M  -498,98 M
# 9      Op. descontinuadas            0         0          0          0
# 10          Lucro líquido     433,56 M  448,72 M  -979,10 M  -498,98 M
# 11      Dos controladores     433,56 M  448,72 M  -979,10 M  -498,98 M
# 12  Dos não controladores            0         0          0          0
#
# 0        2021       2020       2019       2018       2017       2016  \
# 0     35,28 B    29,18 B    19,89 B    15,59 B    11,98 B     9,51 B
# 1    -26,79 B   -21,66 B   -14,33 B   -11,05 B    -8,38 B    -6,59 B
# 2      8,49 B     7,52 B     5,55 B     4,54 B     3,61 B     2,92 B
# 3     -8,02 B    -6,70 B    -4,27 B    -3,46 B    -2,72 B    -2,34 B
# 4    470,60 M   824,58 M     1,29 B     1,08 B   887,69 M   580,95 M
# 5   -689,01 M  -410,50 M   -70,41 M  -294,69 M  -410,82 M  -503,85 M
# 6   -218,41 M   414,08 M     1,22 B   786,86 M   476,87 M    77,10 M
# 7    809,07 M   -22,37 M  -296,32 M  -189,43 M   -87,85 M     9,47 M
# 8    590,66 M   391,71 M   921,83 M   597,43 M   389,02 M    86,56 M
# 9           0          0          0          0          0          0
# 10   590,66 M   391,71 M   921,83 M   597,43 M   389,02 M    86,56 M
# 11   590,66 M   391,71 M   921,83 M   597,43 M   389,02 M    86,56 M
# 12          0          0          0          0          0          0
#
# 0        2015       2014       2013       2012       2011       2010  \
# 0      8,98 B     9,78 B     8,09 B     7,07 B     6,42 B     4,81 B
# 1     -6,40 B    -7,09 B    -5,83 B    -5,06 B    -4,28 B    -3,17 B
# 2      2,58 B     2,69 B     2,26 B     2,01 B     2,14 B     1,64 B
# 3     -2,24 B    -2,20 B    -1,89 B    -1,84 B    -1,93 B    -1,39 B
# 4    338,93 M   490,93 M   374,97 M   166,47 M   213,66 M   251,43 M
# 5   -486,06 M  -360,74 M  -243,96 M  -203,81 M  -165,72 M  -141,47 M
# 6   -147,13 M   130,19 M   131,00 M   -37,34 M    47,94 M   109,97 M
# 7     81,52 M    -1,63 M   -17,20 M    30,59 M   -36,27 M   -41,13 M
# 8    -65,61 M   128,56 M   113,81 M    -6,75 M    11,67 M    68,83 M
# 9           0          0          0          0          0          0
# 10   -65,61 M   128,56 M   113,81 M    -6,75 M    11,67 M    68,83 M
# 11   -65,61 M   128,56 M   113,81 M    -6,75 M    11,67 M    68,83 M
# 12          0          0          0          0          0          0
#
# 0        2009
# 0      3,35 B
# 1     -2,14 B
# 2      1,21 B
# 3     -1,21 B
# 4      3,98 M
# 5   -140,61 M
# 6   -136,63 M
# 7     43,92 M
# 8    -92,71 M
# 9           0
# 10   -92,71 M
# 11   -92,71 M
# 12          0

# %%
df2
# Out:
# 0               Conta      2024       2023     2022      2021       2020  \
# 0  Caixa líq. operac.   15,84 B    15,90 B   3,06 B   -7,57 B     2,60 B
# 1  Dep. e amortização    1,33 B     1,24 B   1,16 B  816,96 M   702,52 M
# 2  Caixa líq. financ.   -1,29 B  -148,40 M  -1,04 B   -1,32 B  -651,45 M
# 3  Caixa líq. invest.  -15,31 B   -15,58 B  -2,17 B    9,77 B  -576,81 M
#
# 0       2019       2018       2017       2016       2015       2014  \
# 0    -3,33 B     1,24 B    19,48 M   267,75 M   462,79 M   131,44 M
# 1   486,98 M   163,69 M   143,06 M   133,61 M   125,80 M   114,33 M
# 2  -928,59 M  -394,11 M  -168,66 M  -135,53 M    60,85 M  -152,93 M
# 3     3,96 B  -655,67 M   -37,25 M  -150,54 M  -318,34 M   153,36 M
#
# 0       2013       2012       2011       2010       2009
# 0  -136,24 M   -25,59 M  -263,58 M   405,41 M   172,56 M
# 1   101,96 M    92,45 M    86,94 M    68,49 M    60,62 M
# 2    53,16 M  -148,78 M  -270,39 M  -105,48 M   203,40 M
# 3   -55,49 M   423,97 M   378,22 M  -163,47 M  -219,05 M

# %%
multp = {'t': 1e12, 'b': 1e9, 'm': 1e6, 'mil': 1e3}

def convert_value(value):
    val_str = str(value).strip().lower()
    parts = val_str.split(' ')

    if len(parts) == 2:
        x, y = parts
        x = x.replace(',', '.')
        x = float(x) * multp.get(y, 1)
        return int(x)
    
    return value

for i in range(0,3):
    var = 'df' + str(i)
    vars()[var][vars()[var].columns[1:]] = vars()[var][vars()[var].columns[1:]].applymap(convert_value)
    print(i)
# Out:
# 0
# 1
# 2
# /tmp/ipykernel_1118/167896165.py:17: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   vars()[var][vars()[var].columns[1:]] = vars()[var][vars()[var].columns[1:]].applymap(convert_value)

# %%
df0_1 = df0.drop(df0.columns[1], axis=1)
df0_1 = df0_1.drop(df0_1.columns[6:], axis=1)
df0_1 = df0_1.drop(df0_1.columns[2:5], axis=1)
# Out:
# 0                     Conta       4T2024       3T2024
# 0               Ativo total  37310000000  35700000000
# 1          Ativo circulante  19550000000  17750000000
# 2      Caixa e eq. de caixa   1830000000   1540000000
# 3    Aplicações financeiras    337890000    269530000
# 4          Contas a receber   5830000000   4780000000
# 5                  Estoques   7610000000   7390000000
# 6         Ativos biológicos            0            0
# 7      Ativo não circulante  17760000000  17960000000
# 8             Investimentos    971860000    898730000
# 9               Imobilizado   5070000000   5040000000
# 10               Intangível   4480000000   4470000000
# 11            Passivo total  37310000000  35700000000
# 12       Passivo circulante  16710000000  14310000000
# 13             Fornecedores  10280000000   9050000000
# 14    Empréstimos e financ.   1400000000    643430000
# 15   Passivo não circulante   9280000000  10330000000
# 16  Emprést. de longo prazo   3180000000   4200000000
# 17       Patrimônio líquido  11320000000  11060000000
# 18    Aos não controladores            0            0

# %%
df1_1 = df1.drop(df1.columns[1], axis=1)
df1_1 = df1_1.drop(df1_1.columns[3:], axis=1)
df1_1
# Out:
# 0                   Conta          2024          2023
# 0         Receita líquida   38040000000   36770000000
# 1                  Custos  -26410000000  -26600000000
# 2             Lucro bruto   11630000000   10160000000
# 3   Despesas operacionais  -10060000000  -10540000000
# 4                    EBIT    1560000000    -372150000
# 5    Resultado financeiro   -1480000000   -1690000000
# 6      Antes dos impostos      87380000   -2060000000
# 7                 Imposto     361330000    1090000000
# 8         Op. continuadas     448720000    -979100000
# 9      Op. descontinuadas             0             0
# 10          Lucro líquido     448720000    -979100000
# 11      Dos controladores     448720000    -979100000
# 12  Dos não controladores             0             0

# %%
df2_1 = df2.drop(df2.columns[3:], axis=1)
df2_1
# Out:
# 0               Conta         2024         2023
# 0  Caixa líq. operac.  15840000000  15900000000
# 1  Dep. e amortização   1330000000   1240000000
# 2  Caixa líq. financ.  -1290000000   -148400000
# 3  Caixa líq. invest. -15310000000 -15580000000

# %%
LL = df1_1[df1_1.columns[1]][10]
Dep_A = df2_1[df2_1.columns[1]][1]
CapEx = sum(df0_1[df0_1.columns[1]][[9,10]])-sum(df0_1[df0_1.columns[2]][[9,10]])
Cap_G = (df0_1[df0_1.columns[1]][1] - df0_1[df0_1.columns[1]][12]) - (df0_1[df0_1.columns[2]][1] - df0_1[df0_1.columns[2]][12])
Div_Liq_E = ((df0_1[df0_1.columns[1]][14] + df0_1[df0_1.columns[1]][16])-(df0_1[df0_1.columns[2]][14] + df0_1[df0_1.columns[2]][16]))-(df0_1[df0_1.columns[1]][2] - df0_1[df0_1.columns[2]][2])
FCFE = LL + Dep_A - CapEx - Cap_G + Div_Liq_E
print(LL)
print(Dep_A)
print(CapEx)
print(Cap_G)
print(Div_Liq_E)
print(FCFE)
# Out:
# 448720000
# 1330000000
# 40000000
# -600000000
# -553430000
# 1785290000

# %%
EBIT = df1_1[df1_1.columns[1]][4]
Tx_Imp = abs(df1_1[df1_1.columns[1]][7]) / df1_1[df1_1.columns[1]][6]
FCFF = EBIT * (1 - Tx_Imp) + Dep_A - CapEx - Cap_G
FCFF
# Out:
# np.float64(-3000844586.8619823)

# %%
def get_info(ticker_base):
    variations = [
        ticker_base,
        f"{ticker_base}.SA"
    ]
    
    for variation in variations:
        try:
            dat = yf.Ticker(variation)
            info = dat.info
            beta = info.get('beta')
            if beta is not None:
                print(f"Info from {ticker_base} successfully retrieved")
                return info
        except Exception:
            continue

    return None

# %%
info = get_info(ticker)
beta = info.get('beta')
####################################
url = 'https://api.bcb.gov.br/dados/serie/bcdata.sgs.1178/dados/ultimos/1?formato=json'
resp = requests.get(url)
selic = float(resp.json()[0].get('valor')) + 0.1
####################################
Mkt_Price = 0.05
####################################
ke = (beta * Mkt_Price) + (selic/100)
ke
# Out:
# HTTP Error 404:
# Info from MGLU3 successfully retrieved
# 0.21655

# %%
Div_Liq = (df0_1[df0_1.columns[1]][14] + df0_1[df0_1.columns[1]][16]) - df0_1[df0_1.columns[1]][2]
P_Liq = df0_1[df0_1.columns[1]][17]
W_Div = Div_Liq / (Div_Liq + P_Liq)
W_P_Liq = P_Liq / (Div_Liq + P_Liq)
WACC = (selic/100) * W_Div * (1 - Tx_Imp) + W_P_Liq * ke
WACC
# Out:
# 0.08230944034039657

# %%
def sect_tx(info):
        setores = {
            'Basic Materials': 0.031,
            'Communication Services': 0.081,
            'Consumer Cyclical': 0.047,
            'Consumer Defensive': 0.035,
            'Energy': 0.034,
            'Financial Services': 0.11,
            'Healthcare': 0.053,
            'Industrials': 0.04,
            'Real Estate': 0.103,
            'Technology': 0.109,
            'Utilities': 0.08
        }
        sector = info.get('sector')
        tx = setores.get(sector, 0.01)
        return tx
YG = sect_tx(info)
LT_G = YG/2
YG
# Out:
# 0.047

# %%
P_FCFF = [FCFF*(1+YG)]
for i in range(0,4):
    P_FCFF.append(P_FCFF[i]*(1+YG))
P_FCFF
# Out:
# [np.float64(-3141884282.444495),
#  np.float64(-3289552843.719386),
#  np.float64(-3444161827.374197),
#  np.float64(-3606037433.260784),
#  np.float64(-3775521192.6240406)]

# %%
present_value = []
for i in range(0,5):
    present_value.append(P_FCFF[i]/(1+WACC)**(i+1))

present_value[4]
# Out:
# np.float64(-2542258333.374892)

# %%
Val_Terminal = P_FCFF[4]*(1+LT_G)/(WACC-LT_G)
ValP_Terminal = Val_Terminal/(1+WACC)**5
Val_Presente_Total = sum(present_value)+ValP_Terminal
Val_Presente_Total
# Out:
# np.float64(-57842678795.59432)

# %%
Eq_Val = Val_Presente_Total-Div_Liq
Eq_Val
# Out:
# np.float64(-60592678795.59432)

# %%
dom = etree.HTML(str(soup))
n_acoes = dom.xpath('/html/body/div[3]/div[1]/div[7]/span[2]')[0].text
n_acoes = int(''.join(n_acoes.split('.')))
n_acoes
# Out:
# 738995248

# %%
Val_Acao = Eq_Val/n_acoes
Val_Acao
# Out:
# np.float64(-81.99332669537588)

# %%
beta
# Out:
# 1.331
